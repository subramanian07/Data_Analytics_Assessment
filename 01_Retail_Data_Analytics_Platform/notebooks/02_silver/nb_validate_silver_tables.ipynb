# %%
# Check silver tables

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_customers LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_order_items LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_orders LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_products LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_returns LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 13, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 538bd4a9-c8be-4741-acd8-6fd5965577fe)
# SynapseWidget(Synapse.DataFrame, 797a4fb0-b2d0-498b-9c7d-b5b54a0dd843)
# SynapseWidget(Synapse.DataFrame, c873325c-33f5-4d6f-8c3f-32f0a87adc01)
# SynapseWidget(Synapse.DataFrame, 2af435d8-f012-43c2-8573-db643480e65d)
# SynapseWidget(Synapse.DataFrame, 2b4e3a65-9428-43f1-921a-6fd7e1fc0bf9)

# %%
# Check silver error tables

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_customers_error LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_order_items_error LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_orders_error LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_products_error LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.silver_returns_error LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 14, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 280a69f3-779b-40f6-97c9-69ff43a57566)
# SynapseWidget(Synapse.DataFrame, 94a8113b-6723-4ea6-97d8-fa300e9814a2)
# SynapseWidget(Synapse.DataFrame, d4c89414-17f0-4d62-84f4-653ca9c08ce2)
# SynapseWidget(Synapse.DataFrame, bd0d9480-6148-4590-bc00-4e3ed0db411c)
# SynapseWidget(Synapse.DataFrame, 96383858-2da8-4bb0-b0b6-64c78a8fefb3)

# %%
# Check schema

print("silver_customers") 
spark.read.table("dbo.silver_customers").printSchema()

print("silver_customers_error") 
spark.read.table("dbo.silver_customers_error").printSchema()

print("silver_products_error") 
spark.read.table("dbo.silver_products_error").printSchema()

print("silver_orders_error") 
spark.read.table("dbo.silver_orders_error").printSchema()

print("silver_order_items_error") 
spark.read.table("dbo.silver_order_items_error").printSchema()

print("silver_returns_error") 
spark.read.table("dbo.silver_returns_error").printSchema()
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 15, Finished, Available, Finished, False)
# silver_customers
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- customer_created_ts: timestamp (nullable = true)
#  |-- ingestion_ts: timestamp (nullable = true)
#  |-- source_file_name: string (nullable = true)
#  |-- pipeline_run_id: string (nullable = true)
#
# silver_customers_error
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- customer_created_ts: timestamp (nullable = true)
#  |-- ingestion_ts: timestamp (nullable = true)
#  |-- source_file_name: string (nullable = true)
#  |-- pipeline_run_id: string (nullable = true)
#  |-- reject_reason: string (nullable = true)
#  |-- reject_ts: timestamp (nullable = true)
#
# silver_products_error
# root
#  |-- product_id: string (nullable = true)
# ...

# %%
df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.ETL.pl_control_config_log ORDER BY step_start_time desc LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 16, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 7b54d7b5-f7aa-4eed-9970-67c5cbf5ac58)
