# %%
# Check Bronze tables

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.bronze_customers LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.bronze_order_items LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.bronze_orders LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.bronze_products LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.bronze_returns LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 95c2291e-0b67-49fe-82d5-a657b59acf35)
# SynapseWidget(Synapse.DataFrame, 36ca92a6-2ae8-4185-8afe-eafcdc01fff6)
# SynapseWidget(Synapse.DataFrame, 6a10d03a-e623-435d-b99d-67230e0ca651)
# SynapseWidget(Synapse.DataFrame, 302294d3-37ba-467b-8d4a-eee04609d376)
# SynapseWidget(Synapse.DataFrame, 727b156b-696f-4333-a246-f2c038ae2042)

# %%
print("bronze_customers") 
spark.read.table("dbo.bronze_customers").printSchema()

print("bronze_products") 
spark.read.table("dbo.bronze_products").printSchema()

print("bronze_orders") 
spark.read.table("dbo.bronze_orders").printSchema()

print("bronze_order_items") 
spark.read.table("dbo.bronze_order_items").printSchema()

print("bronze_returns") 
spark.read.table("dbo.bronze_returns").printSchema()
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 4, Finished, Available, Finished, False)
# bronze_customers
# root
#  |-- customer_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- ingestion_ts: timestamp (nullable = true)
#  |-- source_file_name: string (nullable = true)
#  |-- pipeline_run_id: string (nullable = true)
#
# bronze_products
# root
#  |-- product_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- ingestion_ts: timestamp (nullable = true)
#  |-- source_file_name: string (nullable = true)
#  |-- pipeline_run_id: string (nullable = true)
#
# bronze_orders
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_date: string (nullable = true)
# ...

# %%
df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.ETL.pl_control_config_log ORDER BY step_start_time desc LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 20cfc748-ff65-4f76-b0c7-bf7f4ae13859)
