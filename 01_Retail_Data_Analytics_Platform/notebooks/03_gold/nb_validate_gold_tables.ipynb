# %%
# Check gold dim and fact tables

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.dim_customer LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.dim_date LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.dim_product LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.fact_sales LIMIT 1000")
display(df)

df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.dbo.fact_returns LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 29, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 5e630248-45da-4222-9d23-e01b2cc93ac2)
# SynapseWidget(Synapse.DataFrame, b1ddd345-1931-4131-aabc-74cec83caa15)
# SynapseWidget(Synapse.DataFrame, d248e4a9-087b-4198-ae4b-0696a634bc89)
# SynapseWidget(Synapse.DataFrame, 62c32351-5f21-4dda-a54e-cf3f7509bea8)
# SynapseWidget(Synapse.DataFrame, 55f0c9d2-4b90-403f-941b-ff0dbc916e2b)

# %%
# Check schema

print("dim_customer") 
spark.read.table("dbo.dim_customer").printSchema()

print("dim_date") 
spark.read.table("dbo.dim_date").printSchema()

print("dim_product") 
spark.read.table("dbo.dim_product").printSchema()

print("fact_sales") 
spark.read.table("dbo.fact_sales").printSchema()

print("fact_returns") 
spark.read.table("dbo.fact_returns").printSchema()
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 30, Finished, Available, Finished, False)
# dim_customer
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_name: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- customer_created_ts: timestamp (nullable = true)
#  |-- is_current: boolean (nullable = true)
#  |-- effective_from: timestamp (nullable = true)
#  |-- effective_to: timestamp (nullable = true)
#
# dim_date
# root
#  |-- date: date (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)
#  |-- quarter: integer (nullable = true)
#
# dim_product
# root
#  |-- product_id: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- unit_price: decimal(18,2) (nullable = true)
#
# fact_sales
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
# ...

# %%
df = spark.sql("SELECT * FROM Retail_Analytics_Lakehouse.ETL.pl_control_config_log ORDER BY step_start_time desc LIMIT 1000")
display(df)
# Out:
# StatementMeta(, c5809b39-7928-41d1-a848-9c12345bbfe7, 31, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, a945e275-c550-4279-8f8d-2e7e18f15db9)
